# %%
import galprime as gp

from galprime import plotting
import glob, os

from astropy.table import Table

from astropy.io import fits

import numpy as np

# %%
pp = gp.plotting.ProfilePlot(outdir="gprime_primary/", outname="profile_plot.pdf")
pp.plot(width=8, nmodels=1000, third_index=1, ylim=[35, 25])
pp.save()
# Out:
# /Users/hsouch/GalPRIME/galprime/utils/fluxes.py:8: RuntimeWarning: invalid value encountered in log10
#   sb = -2.5 * np.log10(f / (arcconv ** 2)) + m_0
# /Users/hsouch/GalPRIME/galprime/utils/fluxes.py:8: RuntimeWarning: divide by zero encountered in log10
#   sb = -2.5 * np.log10(f / (arcconv ** 2)) + m_0

# %%
    
dp = gp.plotting.DiffPlot(outdir="gprime_primary/", outname="diff_plot.pdf")
dp.plot(width=8, nmodels=1000, third_index=1, xlim=[2, 50])
