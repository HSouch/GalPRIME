# %%
import galprime as gp

c = gp.default_config()

# %%
test_kde = gp.UniformSSKDE().generate()

models = gp.SingleSersicModel(size=851).gen_multiple(c, kde=test_kde)

# %%
gp.plotting.show_cutouts(models, model_data=models.cutout_data)
# Out:
# 100
