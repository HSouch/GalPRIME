# %%
import galprime as gp

c = gp.default_config()

# %%
test_kde = gp.UniformSSKDE().generate()

models = gp.SingleSersicModel().gen_multiple(c, kde=test_kde)

# %%
gp.plotting.show_cutouts(models)
# Out:
# 100
